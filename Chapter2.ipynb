# %%
# !git config --global user.name 'Jerica Thea Jalbuena'
# !git config --global user.email 'jericathea.jalbuena@students.isatu.edu.ph'
print('done')
# !git config --global user.password =  #password should be the token
# Out:
# done

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: e
# Hello e

# %%
#Write a program to prompt the user for hours and rate per hour to compute gross pay.
hours_str = input('Enter Hours: ')
hours = float(hours_str)

rate_str = input('Enter Rate: ')
rate = float(rate_str)

gross_pay = hours * rate

print('Pay:', gross_pay)
# Out:
# Enter Hours: 2
# Enter Rate: 3
# Pay: 6.0

# %%
#Assume that we execute the following assignment statements:
#For each of the following expressions, write the value of the expression and the type (of the value of the expression).
width = 17
height = 12.0

result1 = width // 2
print(f"width//2: Value = {result1}, Type = {type(result1)}")

result2 = width / 2.0
print(f"width/2.0: Value = {result2}, Type = {type(result2)}")

result3 = height / 3
print(f"height/3: Value = {result3}, Type = {type(result3)}")

result4 = 1 + 2 * 5
print(f"1 + 2 * 5: Value = {result4}, Type = {type(result4)}")
# Out:
# width//2: Value = 8, Type = <class 'int'>
# width/2.0: Value = 8.5, Type = <class 'float'>
# height/3: Value = 4.0, Type = <class 'float'>
# 1 + 2 * 5: Value = 11, Type = <class 'int'>

# %%
#Write a program that uses input to prompt a user for a number and then outputs the square of the number
num_str = input('Enter a number: ')
num = float(num_str)
square = num * num
print(f'The square of {num} is {square}')
# Out:
# Enter a number: 43
# The square of 43.0 is 1849.0

# %%
#Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.
celsius_str = input('Enter temperature in Celsius: ')
celsius = float(celsius_str)
fahrenheit = (celsius * 9/5) + 32
print(f'The temperature in Fahrenheit is {fahrenheit}')
# Out:
# Enter temperature in Celsius: 11
# The temperature in Fahrenheit is 51.8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# changing the working directory
# %cd /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena

# %%
ls
# Out:
#  Chapter2.ipynb                                          NewUpload.txt
#  Copy_of_01_Python_Fundamentals,_Part_1_Workbook.ipynb   PythonEnvi_Jalbuena/
# 'Copy of (IS110)Using_Git on Google Colab.ipynb'         Untitled0.ipynb
#  IS110_repo_Jalbuena/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena
# Out:
# /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena

# %%
#copy files to the working directory

# !cp "/content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/Chapter2.ipynb" "/content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/IS110_repo_Jalbuena"
#!cp "/content/drive/MyDrive/ColabNotebooks/Python_Fundamentals/00 Jupyter Notebooks Tutorial (Workbook).ipynb" "/content/AppDev_Jamile/worksheet#1"

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/IS110_repo_Jalbuena
# Out:
# /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/IS110_repo_Jalbuena

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/IS110_repo_Jalbuena

# %%
# !touch world.py #make sure that the path points of your repo

#check the file if it is added in the repo just double click the folder
print('Done')
# Out:
# Done

# %%
# %ls
# Out:
# Chapter2.ipynb                                         NewUpload.txt
# Copy_of_01_Python_Fundamentals,_Part_1_Workbook.ipynb  PythonEnvi_Jalbuena/
# IS110_repo_Jalbuena/                                   world.py

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/IS110_BPerformance_Jalbuena/IS110_repo_Jalbuena/.git/

# %%
# !git add Chapter2.ipynb

# %%
# !git log --oneline
# Out:
# c0875c0 (HEAD -> main) Add Chapter2.ipynb
# fdaf188 (origin/main) Add Chapter2.ipynb
# 68f66e8 new commit
# a473c9b new commit

# %%
# !git reset --hard HEAD~1
# Out:
# HEAD is now at fdaf188 Add Chapter2.ipynb

# %%
# !git commit -m "Chapter2.ipynb"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	IS110_repo_Jalbuena/
# 	PythonEnvi_Jalbuena/
# 	world.py
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git reset --hard HEAD~1
# Out:
# HEAD is now at 68f66e8 new commit

# %%
# !git push origin main --force
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/jericatheajalbuena-bit/IS110_repo_Jalbuena.git
#  + fdaf188...68f66e8 main -> main (forced update)
